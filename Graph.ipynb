# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ROMEO\AppData\Roaming\Python\Python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\ROMEO\AppData\Roaming\Python\Python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ROMEO\AppData\Local\Programs\Python\Python311\python.exe

# %%
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\ROMEO\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\ROMEO\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\ROMEO\AppData\Roaming\Python\Python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\ROMEO\AppData\Roaming\Python\Python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
data=[1, 2, 3, 4, 5]

# %%
import matplotlib.pyplot as plt

plt.plot(data)
plt.show()

# %%
data = [1,2,3,4,5,6,78,8,9,10,11,34,56,43,56,67]

# %%
plt.plot(data)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Iris.csv")

plt.plot(df["SepalLengthCm"])
plt.show()

# %%
import matplotlib.pyplot as plt

data = [10, 20, 15, 30, 25]

plt.plot(data)
plt.title("Simple Line Plot")
plt.xlabel("Index")
plt.ylabel("Value")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

plt.plot(x, y, marker='o', linestyle='--')
plt.title("Line Plot with Markers")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt

subjects = ["Math", "English", "Science", "Computer"]
marks = [80, 75, 90, 95]

plt.bar(subjects, marks)
plt.title("Student Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [5, 8, 2, 10, 7]

plt.scatter(x, y)
plt.title("Scatter Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ["Python", "Java", "C++", "JavaScript"]
sizes = [40, 25, 20, 15]

plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title("Programming Languages")
plt.show()
